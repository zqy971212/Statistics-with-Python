# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
sample_data = pd.read_csv('Book1.csv')

# %%
sample_data = pd.read_csv('Book1.csv')

# %%
sample_data
# Out:
#                   School  Time Of Reading Each Week(Hours  GPA
# 0     Peking University                                 9  2.9
# 1     Peking University                                 5  3.0
# 2     Peking University                                10  3.1
# 3     Peking University                                30  3.1
# 4     Peking University                                 8  3.2
# 5     Peking University                                20  3.3
# 6     Peking University                                25  3.5
# 7     Peking University                                13  3.5
# 8     Peking University                                35  3.5
# 9     Peking University                                10  3.1
# 10    Peking University                                20  3.6
# 11    Peking University                                18  3.6
# 12    Peking University                                15  3.8
# 13    Peking University                                30  3.9
# 14    Peking University                                31  4.0
# 15  ShenzhenPolytechnic                                 3  1.7
# 16  ShenzhenPolytechnic                                 1  1.4
# 17  ShenzhenPolytechnic                                 2  2.0
# 18  ShenzhenPolytechnic                                 5  2.5
# 19  ShenzhenPolytechnic                                 3  2.1
# 20  ShenzhenPolytechnic                                 2  2.8
# 21  ShenzhenPolytechnic                                 5  3.0
# 22  ShenzhenPolytechnic                                 3  2.4
# 23  ShenzhenPolytechnic                                 4  3.1
# 24  ShenzhenPolytechnic                                15  3.1
# 25  ShenzhenPolytechnic                                 1  2.2
# 26  ShenzhenPolytechnic                                11  3.3
# 27  ShenzhenPolytechnic                                 8  3.4
# 28  ShenzhenPolytechnic                                15  3.6
# 29  ShenzhenPolytechnic                                10  3.8
# 30    Shenzhen Universiy                                8  3.3
# 31    Shenzhen Universiy                               15  3.7
# 32    Shenzhen Universiy                                4  3.1
# 33    Shenzhen Universiy                                7  2.9
# 34    Shenzhen Universiy                               20  3.8
# 35    Shenzhen Universiy                               40  4.0
# 36    Shenzhen Universiy                               33  3.8
# 37    Shenzhen Universiy                                5  2.7
# 38    Shenzhen Universiy                               10  3.5
# 39    Shenzhen Universiy                               10  3.2
# 40    Shenzhen Universiy                               27  3.6
# 41    Shenzhen Universiy                               22  3.1
# 42    Shenzhen Universiy                               36  4.0
# 43    Shenzhen Universiy                                8  2.6
# 44    Shenzhen Universiy                               18  2.9

# %%
plt.plot(sample_data.Time Of Reading Each Week(Hours,sample_data.GPA)
# Out:
#   File "<ipython-input-9-70009ed9fb97>", line 1
#     plt.plot(sample_data.Time Of Reading Each Week(Hours,sample_data.GPA)
#                                ^
# SyntaxError: invalid syntax

# %%
plt.plot(sample_data.Time Of Reading Each Week Hours, smaple_data.GPA))
plt.show()
# Out:
#   File "<ipython-input-10-b34acd82de84>", line 1
#     plt.plot(sample_data.Time Of Reading Each Week Hours, smaple_data.GPA))
#                                ^
# SyntaxError: invalid syntax

# %%
sample_data = pd.read_csv('Book1.csv')

# %%
plt.plot(sample_data.Time Of Reading Each Week Hours, smaple_data.GPA))

plt.show()
# Out:
#   File "<ipython-input-12-de3c8a0a8bab>", line 1
#     plt.plot(sample_data.Time Of Reading Each Week Hours, smaple_data.GPA))
#                                ^
# SyntaxError: invalid syntax

# %%
sample_data
# Out:
#                   School  Time Of Reading Each Week  GPA
# 0     Peking University                           9  2.9
# 1     Peking University                           5  3.0
# 2     Peking University                          10  3.1
# 3     Peking University                          30  3.1
# 4     Peking University                           8  3.2
# 5     Peking University                          20  3.3
# 6     Peking University                          25  3.5
# 7     Peking University                          13  3.5
# 8     Peking University                          35  3.5
# 9     Peking University                          10  3.1
# 10    Peking University                          20  3.6
# 11    Peking University                          18  3.6
# 12    Peking University                          15  3.8
# 13    Peking University                          30  3.9
# 14    Peking University                          31  4.0
# 15  ShenzhenPolytechnic                           3  1.7
# 16  ShenzhenPolytechnic                           1  1.4
# 17  ShenzhenPolytechnic                           2  2.0
# 18  ShenzhenPolytechnic                           5  2.5
# 19  ShenzhenPolytechnic                           3  2.1
# 20  ShenzhenPolytechnic                           2  2.8
# 21  ShenzhenPolytechnic                           5  3.0
# 22  ShenzhenPolytechnic                           3  2.4
# 23  ShenzhenPolytechnic                           4  3.1
# 24  ShenzhenPolytechnic                          15  3.1
# 25  ShenzhenPolytechnic                           1  2.2
# 26  ShenzhenPolytechnic                          11  3.3
# 27  ShenzhenPolytechnic                           8  3.4
# 28  ShenzhenPolytechnic                          15  3.6
# 29  ShenzhenPolytechnic                          10  3.8
# 30    Shenzhen Universiy                          8  3.3
# 31    Shenzhen Universiy                         15  3.7
# 32    Shenzhen Universiy                          4  3.1
# 33    Shenzhen Universiy                          7  2.9
# 34    Shenzhen Universiy                         20  3.8
# 35    Shenzhen Universiy                         40  4.0
# 36    Shenzhen Universiy                         33  3.8
# 37    Shenzhen Universiy                          5  2.7
# 38    Shenzhen Universiy                         10  3.5
# 39    Shenzhen Universiy                         10  3.2
# 40    Shenzhen Universiy                         27  3.6
# 41    Shenzhen Universiy                         22  3.1
# 42    Shenzhen Universiy                         36  4.0
# 43    Shenzhen Universiy                          8  2.6
# 44    Shenzhen Universiy                         18  2.9

# %%
plt.plot(sample_data.Time Of Reading Each Week, sample_data.GPA)
plt.show()
# Out:
#   File "<ipython-input-14-a0a9c35f6fc7>", line 1
#     plt.plot(sample_data.Time Of Reading Each Week, sample_data.GPA)
#                                ^
# SyntaxError: invalid syntax

# %%
sample_data = pd.read_csv('Book1.csv')

# %%
smaple.data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e2a6348b87b4> in <module>
# ----> 1 smaple.data
#
# NameError: name 'smaple' is not defined

# %%
sample_data
# Out:
#                   School  Time  GPA
# 0     Peking University      9  2.9
# 1     Peking University      5  3.0
# 2     Peking University     10  3.1
# 3     Peking University     30  3.1
# 4     Peking University      8  3.2
# 5     Peking University     20  3.3
# 6     Peking University     25  3.5
# 7     Peking University     13  3.5
# 8     Peking University     35  3.5
# 9     Peking University     10  3.1
# 10    Peking University     20  3.6
# 11    Peking University     18  3.6
# 12    Peking University     15  3.8
# 13    Peking University     30  3.9
# 14    Peking University     31  4.0
# 15  ShenzhenPolytechnic      3  1.7
# 16  ShenzhenPolytechnic      1  1.4
# 17  ShenzhenPolytechnic      2  2.0
# 18  ShenzhenPolytechnic      5  2.5
# 19  ShenzhenPolytechnic      3  2.1
# 20  ShenzhenPolytechnic      2  2.8
# 21  ShenzhenPolytechnic      5  3.0
# 22  ShenzhenPolytechnic      3  2.4
# 23  ShenzhenPolytechnic      4  3.1
# 24  ShenzhenPolytechnic     15  3.1
# 25  ShenzhenPolytechnic      1  2.2
# 26  ShenzhenPolytechnic     11  3.3
# 27  ShenzhenPolytechnic      8  3.4
# 28  ShenzhenPolytechnic     15  3.6
# 29  ShenzhenPolytechnic     10  3.8
# 30    Shenzhen Universiy     8  3.3
# 31    Shenzhen Universiy    15  3.7
# 32    Shenzhen Universiy     4  3.1
# 33    Shenzhen Universiy     7  2.9
# 34    Shenzhen Universiy    20  3.8
# 35    Shenzhen Universiy    40  4.0
# 36    Shenzhen Universiy    33  3.8
# 37    Shenzhen Universiy     5  2.7
# 38    Shenzhen Universiy    10  3.5
# 39    Shenzhen Universiy    10  3.2
# 40    Shenzhen Universiy    27  3.6
# 41    Shenzhen Universiy    22  3.1
# 42    Shenzhen Universiy    36  4.0
# 43    Shenzhen Universiy     8  2.6
# 44    Shenzhen Universiy    18  2.9

# %%
plt.plot(sample_data.Time, sample_data.GPA)
plt.show()

# %%
sample_data = pd.read_csv('Book1.csv')

# %%
smaple_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-73db4ece330d> in <module>
# ----> 1 smaple_data
#
# NameError: name 'smaple_data' is not defined

# %%
smaple_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-73db4ece330d> in <module>
# ----> 1 smaple_data
#
# NameError: name 'smaple_data' is not defined

# %%
sample_data
# Out:
#                   School  Time  GPA
# 0   ShenzhenPolytechnic      1  1.4
# 1   ShenzhenPolytechnic      3  1.7
# 2   ShenzhenPolytechnic      2  2.0
# 3   ShenzhenPolytechnic      3  2.1
# 4   ShenzhenPolytechnic      1  2.2
# 5   ShenzhenPolytechnic      3  2.4
# 6   ShenzhenPolytechnic      5  2.5
# 7     Shenzhen Universiy     8  2.6
# 8     Shenzhen Universiy     5  2.7
# 9   ShenzhenPolytechnic      2  2.8
# 10    Peking University      9  2.9
# 11    Shenzhen Universiy     7  2.9
# 12    Shenzhen Universiy    18  2.9
# 13    Peking University      5  3.0
# 14  ShenzhenPolytechnic      5  3.0
# 15    Peking University     10  3.1
# 16    Peking University     30  3.1
# 17    Peking University     10  3.1
# 18  ShenzhenPolytechnic      4  3.1
# 19  ShenzhenPolytechnic     15  3.1
# 20    Shenzhen Universiy     4  3.1
# 21    Shenzhen Universiy    22  3.1
# 22    Peking University      8  3.2
# 23    Shenzhen Universiy    10  3.2
# 24    Peking University     20  3.3
# 25  ShenzhenPolytechnic     11  3.3
# 26    Shenzhen Universiy     8  3.3
# 27  ShenzhenPolytechnic      8  3.4
# 28    Peking University     25  3.5
# 29    Peking University     13  3.5
# 30    Peking University     35  3.5
# 31    Shenzhen Universiy    10  3.5
# 32    Peking University     20  3.6
# 33    Peking University     18  3.6
# 34  ShenzhenPolytechnic     15  3.6
# 35    Shenzhen Universiy    27  3.6
# 36    Shenzhen Universiy    15  3.7
# 37    Peking University     15  3.8
# 38  ShenzhenPolytechnic     10  3.8
# 39    Shenzhen Universiy    20  3.8
# 40    Shenzhen Universiy    33  3.8
# 41    Peking University     30  3.9
# 42    Peking University     31  4.0
# 43    Shenzhen Universiy    40  4.0
# 44    Shenzhen Universiy    36  4.0

# %%
plt.plot(sample_data.Time, sample_data.GPA)
plt.show()

# %%
plt.plot(sample_data.Time, sample_data.GPA,'o')
plt.show()

# %%
# COMPARE the GPA BETWEEN DIFFERENT SCHOOL

# %%
PU = data[data.School =='Peking University']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-32ef300a528a> in <module>
# ----> 1 PU = data[data.School =='Peking University']
#
# NameError: name 'data' is not defined

# %%
PU = sample_data[sample_data.School=='Peking University']

# %%
PU
# Out:
# Empty DataFrame
# Columns: [School, Time, GPA]
# Index: []

# %%
PU = sample_data[sample_data.School=='Shenzhen Universiy']

# %%
SU = sample_data[sample_data.School=='Shenzhen Universiy']

# %%
PU = sample_data[sample_data.School=='Peking University']

# %%
PU
# Out:
# Empty DataFrame
# Columns: [School, Time, GPA]
# Index: []

# %%
PU = sample_data[sample_data.School=='Peking University ']

# %%
PU
# Out:
#                 School  Time  GPA
# 10  Peking University      9  2.9
# 13  Peking University      5  3.0
# 15  Peking University     10  3.1
# 16  Peking University     30  3.1
# 17  Peking University     10  3.1
# 22  Peking University      8  3.2
# 24  Peking University     20  3.3
# 28  Peking University     25  3.5
# 29  Peking University     13  3.5
# 30  Peking University     35  3.5
# 32  Peking University     20  3.6
# 33  Peking University     18  3.6
# 37  Peking University     15  3.8
# 41  Peking University     30  3.9
# 42  Peking University     31  4.0

# %%
PU = sample_data[sample_data.School=='ShenzhenPolytechnic ']

# %%
PU = sample_data[sample_data.School=='Peking University ']

# %%
SP = sample_data[sample_data.School=='ShenzhenPolytechnic ']

# %%
PU
# Out:
#                 School  Time  GPA
# 10  Peking University      9  2.9
# 13  Peking University      5  3.0
# 15  Peking University     10  3.1
# 16  Peking University     30  3.1
# 17  Peking University     10  3.1
# 22  Peking University      8  3.2
# 24  Peking University     20  3.3
# 28  Peking University     25  3.5
# 29  Peking University     13  3.5
# 30  Peking University     35  3.5
# 32  Peking University     20  3.6
# 33  Peking University     18  3.6
# 37  Peking University     15  3.8
# 41  Peking University     30  3.9
# 42  Peking University     31  4.0

# %%
SP
# Out:
#                   School  Time  GPA
# 0   ShenzhenPolytechnic      1  1.4
# 1   ShenzhenPolytechnic      3  1.7
# 2   ShenzhenPolytechnic      2  2.0
# 3   ShenzhenPolytechnic      3  2.1
# 4   ShenzhenPolytechnic      1  2.2
# 5   ShenzhenPolytechnic      3  2.4
# 6   ShenzhenPolytechnic      5  2.5
# 9   ShenzhenPolytechnic      2  2.8
# 14  ShenzhenPolytechnic      5  3.0
# 18  ShenzhenPolytechnic      4  3.1
# 19  ShenzhenPolytechnic     15  3.1
# 25  ShenzhenPolytechnic     11  3.3
# 27  ShenzhenPolytechnic      8  3.4
# 34  ShenzhenPolytechnic     15  3.6
# 38  ShenzhenPolytechnic     10  3.8

# %%
SU
# Out:
#                 School  Time  GPA
# 7   Shenzhen Universiy     8  2.6
# 8   Shenzhen Universiy     5  2.7
# 11  Shenzhen Universiy     7  2.9
# 12  Shenzhen Universiy    18  2.9
# 20  Shenzhen Universiy     4  3.1
# 21  Shenzhen Universiy    22  3.1
# 23  Shenzhen Universiy    10  3.2
# 26  Shenzhen Universiy     8  3.3
# 31  Shenzhen Universiy    10  3.5
# 35  Shenzhen Universiy    27  3.6
# 36  Shenzhen Universiy    15  3.7
# 39  Shenzhen Universiy    20  3.8
# 40  Shenzhen Universiy    33  3.8
# 43  Shenzhen Universiy    40  4.0
# 44  Shenzhen Universiy    36  4.0

# %%
plt.plot(PU.GPA, PU.Time 'o')
plt.plot(SP.GPA, SP.Time 'o')
plt.plot(SU.GPA, SU.Time 'o')
plt.legend(['PU', 'SP', 'SU'])
plt.xlabel('GPA')
plt.ylabel('Reading time')
plt.show()
# Out:
#   File "<ipython-input-42-24ba2a783642>", line 1
#     plt.plot(PU.GPA, PU.Time 'o')
#                                ^
# SyntaxError: invalid syntax

# %%
plt.plot(PU.GPA, PU.Time, 'o')
plt.plot(SP.GPA, SP.Time, 'o')
plt.plot(SU.GPA, SU.Time,'o')
plt.legend(['PU', 'SP', 'SU'])
plt.xlabel('GPA')
plt.ylabel('Reading time')
plt.show()
